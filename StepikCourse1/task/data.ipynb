# %%
# Здесь должен быть твой код
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('genome_matrix.csv', index_col=0)
df.head()
g = sns.heatmap(df, cmap="viridis")  #(df, cmap="viridis)
# g = # ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы index_col=0c:\Users\Main\Downloads\genome_matrix.csv
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)
